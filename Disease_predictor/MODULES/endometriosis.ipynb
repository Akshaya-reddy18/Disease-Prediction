# %%
pip install pandas scikit-learn pickle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
endometriosis_dataset = pd.read_csv("../datasets/endometriosis.csv")

# %%
endometriosis_dataset.head()
# Out:
#    Age   BMI  MenstrualCycleLength  MenstrualFlowIntensity  PelvicPainScore  \
# 0   18  18.0                    25                       1                0
# 1   19  18.5                    26                       2                1
# 2   20  19.0                    27                       3                2
# 3   21  19.5                    28                       1                3
# 4   22  20.0                    29                       2                4
#
#    InfertilityHistory  FamilyHistory  BiomarkerLevel  Outcome
# 0                   0              0            10.0        0
# 1                   0              0            11.0        0
# 2                   0              1            12.0        0
# 3                   1              0            13.0        0
# 4                   0              0            14.0        1

# %%
endometriosis_dataset.shape
# Out:
# (168, 9)

# %%
endometriosis_dataset.describe()
# Out:
#               Age         BMI  MenstrualCycleLength  MenstrualFlowIntensity  \
# count  168.000000  168.000000            168.000000              168.000000
# mean    29.785714   26.919048             29.892857                1.994048
# std      7.697222    5.199170              3.083733                0.815252
# min     18.000000   18.000000             25.000000                1.000000
# 25%     23.000000   22.500000             27.000000                1.000000
# 50%     29.000000   27.000000             30.000000                2.000000
# 75%     36.000000   31.500000             32.250000                3.000000
# max     45.000000   35.500000             35.000000                3.000000
#
#        PelvicPainScore  InfertilityHistory  FamilyHistory  BiomarkerLevel  \
# count       168.000000          168.000000     168.000000      168.000000
# mean          5.047619            0.172619       0.297619       15.327976
# ...

# %%
endometriosis_dataset['Outcome']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 163    0
# 164    1
# 165    0
# 166    0
# 167    0
# Name: Outcome, Length: 168, dtype: int64

# %%
endometriosis_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    131
# 1     37
# Name: count, dtype: int64

# %%
endometriosis_dataset['Outcome'].mean()
# Out:
# 0.22023809523809523

# %%
x = endometriosis_dataset.drop(columns=['Outcome'], axis=1)
y = endometriosis_dataset['Outcome']

# %%
x.head()
# Out:
#    Age   BMI  MenstrualCycleLength  MenstrualFlowIntensity  PelvicPainScore  \
# 0   18  18.0                    25                       1                0
# 1   19  18.5                    26                       2                1
# 2   20  19.0                    27                       3                2
# 3   21  19.5                    28                       1                3
# 4   22  20.0                    29                       2                4
#
#    InfertilityHistory  FamilyHistory  BiomarkerLevel
# 0                   0              0            10.0
# 1                   0              0            11.0
# 2                   0              1            12.0
# 3                   1              0            13.0
# 4                   0              0            14.0

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (134, 8)

# %%
x_test.shape
# Out:
# (34, 8)

# %%
x_train.head()
# Out:
#      Age   BMI  MenstrualCycleLength  MenstrualFlowIntensity  PelvicPainScore  \
# 69    31  34.5                    28                       1                3
# 136   27  32.0                    29                       2                4
# 2     20  19.0                    27                       3                2
# 93    27  28.5                    30                       1                5
# 134   25  31.0                    27                       3                2
#
#      InfertilityHistory  FamilyHistory  BiomarkerLevel
# 69                    0              1            13.0
# 136                   0              0            14.0
# 2                     0              1            12.0
# 93                    0              0            15.0
# 134                   0              1            12.0

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7941176470588235

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pickle
filename = 'endometriosis_model.sav'
pickle.dump(model,open(filename,'wb'))
